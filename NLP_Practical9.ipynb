# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\muthu\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\muthu\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    -------------------------------------- 624.3/624.3 kB 703.2 kB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0

# %%
from textblob import TextBlob

# %%
#Sample reviews
reviews = [
    "I love this prodect, it is amazing!",
    "This is the worst purchase I never made.",
    "The product is okey, not great."
]

# %%
#statement analysis
for review in reviews:
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity
    if polarity>0:
        sentiment = "positive"
    elif polarity<0:
        sentiment = "Negative"
    else:
        sentiment = "Natural"
    print(f"Review: {review}\nSentiment:{sentiment}\nPolarity:{polarity}\n")
# Out:
# Review: I love this prodect, it is amazing!
# Sentiment:positive
# Polarity:0.625
#
# Review: This is the worst purchase I never made.
# Sentiment:Negative
# Polarity:-1.0
#
# Review: The product is okey, not great.
# Sentiment:Negative
# Polarity:-0.4
