# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\muthu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.probability import FreqDist

# %%
text = "Language modeling is an important part of Natural Language Processing."

# %%
tokens = word_tokenize(text.lower())

# %%
#General N grams (n=2)
bigrams = list(ngrams(tokens,2))

# %%
freq= FreqDist(bigrams)

# %%
print("Bigram Frequency:")
for k, v in freq.items():
    print(k, ":", v)
# Out:
# Bigram Frequency:
# ('language', 'modeling') : 1
# ('modeling', 'is') : 1
# ('is', 'an') : 1
# ('an', 'important') : 1
# ('important', 'part') : 1
# ('part', 'of') : 1
# ('of', 'natural') : 1
# ('natural', 'language') : 1
# ('language', 'processing') : 1
# ('processing', '.') : 1

# %%
print("\nMost Common Bigram:")
print(freq.most_common(5))
# Out:
# Most Common Bigram:
# [(('language', 'modeling'), 1), (('modeling', 'is'), 1), (('is', 'an'), 1), (('an', 'important'), 1), (('important', 'part'), 1)]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\muthu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.probability import FreqDist

# %%
text = "Natural language processing enables machine to understand human language."

# %%
tokens = word_tokenize(text.lower())

# %%
unigrams = tokens
bigrams = list(ngrams(tokens, 2))
trigrams = list(ngrams(tokens, 3))

# %%
print("Unigrams:", unigrams)
print("Bigrams:", bigrams)
print("Trigrams:", trigrams)
# Out:
# Unigrams: ['natural', 'language', 'processing', 'enables', 'machine', 'to', 'understand', 'human', 'language', '.']
# Bigrams: [('natural', 'language'), ('language', 'processing'), ('processing', 'enables'), ('enables', 'machine'), ('machine', 'to'), ('to', 'understand'), ('understand', 'human'), ('human', 'language'), ('language', '.')]
# Trigrams: [('natural', 'language', 'processing'), ('language', 'processing', 'enables'), ('processing', 'enables', 'machine'), ('enables', 'machine', 'to'), ('machine', 'to', 'understand'), ('to', 'understand', 'human'), ('understand', 'human', 'language'), ('human', 'language', '.')]

# %%
print("\nMost Common Unigrams:")
print(FreqDist(unigrams).most_common(5))
# Out:
# Most Common Unigrams:
# [('language', 2), ('natural', 1), ('processing', 1), ('enables', 1), ('machine', 1)]

# %%
print("Most Common Bigrams:")
print(FreqDist(bigrams).most_common(5))
# Out:
# Most Common Bigrams:
# [(('natural', 'language'), 1), (('language', 'processing'), 1), (('processing', 'enables'), 1), (('enables', 'machine'), 1), (('machine', 'to'), 1)]

# %%
print("Most Common Trigram:")
print(FreqDist(trigrams).most_common(5))
# Out:
# Most Common Trigram:
# [(('natural', 'language', 'processing'), 1), (('language', 'processing', 'enables'), 1), (('processing', 'enables', 'machine'), 1), (('enables', 'machine', 'to'), 1), (('machine', 'to', 'understand'), 1)]
